# %% [markdown]
# # Pacotes necessários

# %%
# !pip install --upgrade pip
# !pip install pymongo
# !pip install requests
# !pip install pika
# !pip install pysqlite3

# %% [markdown]
# # Vamos primeiro conectar com o mongo e excluir todos os Pokemons existentes

# %%
from pymongo import MongoClient

# Configuração do banco de dados
MONGO_URI = "mongodb://localhost:27017/"
DATABASE_NAME = "pokedex"
COLLECTION_NAME = "pokemons"

# Conectando ao MongoDB
client = MongoClient(MONGO_URI)
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

# Deletando todos os documentos da collection
result = collection.delete_many({})

# Informando o resultado
print(f"{result.deleted_count} documentos foram deletados.")
# Out:
# 168 documentos foram deletados.

# %% [markdown]
# # Agora vamos conectar com a PokeAPI e reabastecer a nossa Pokedex no Mongo

# %%
import requests
import pymongo
import time

# URL do endpoint da PokeAPI
url = "https://pokeapi.co/api/v2/pokemon/?offset=0&limit=151"

# Conectando com o MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["pokedex"]
collection = db["pokemons"]

# Fazendo a requisição HTTP
response = requests.get(url)

# Verificando se a requisição foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()

    # Obtendo a lista de pokémons
    pokemons = data["results"]

    for index, pokemon in enumerate(pokemons):
        pokemon_url = pokemon["url"]
        print(f"Obtendo dados para o Pokémon {index + 1}/{len(pokemons)}: {pokemon['name']}")

        pokemon_data = requests.get(pokemon_url).json()

        # Estruturando os dados para inserção no MongoDB
        record = {
            "name": pokemon_data["name"],
            "url": pokemon_url,
            "abilities": [ability["ability"]["name"] for ability in pokemon_data["abilities"]],
            "base_experience": pokemon_data["base_experience"],
            "forms": pokemon_data["forms"],
            "game_indices": pokemon_data["game_indices"],
            "height": pokemon_data["height"],
            "held_items": pokemon_data["held_items"],
            "id": pokemon_data["id"],
            "is_default": pokemon_data["is_default"],
            "location_area_encounters": pokemon_data["location_area_encounters"],
            "moves": pokemon_data["moves"],
            "n_order": pokemon_data["order"],
            "past_types": pokemon_data["past_types"],
            "species": pokemon_data["species"],
            "sprites": pokemon_data["sprites"],
            "stats": pokemon_data["stats"],
            "types": pokemon_data["types"],
            "weight": pokemon_data["weight"]
        }

        # Inserindo o registro no MongoDB
        collection.insert_one(record)

        # Aguarde antes de fazer a próxima requisição
        # time.sleep(0.3)

    print("Pokémons inseridos com sucesso no MongoDB!")
else:
    print(f"Erro ao acessar a API da PokeAPI. Código de status: {response.status_code}")
# Out:
# Obtendo dados para o Pokémon 1/151: bulbasaur
# Obtendo dados para o Pokémon 2/151: ivysaur
# Obtendo dados para o Pokémon 3/151: venusaur
# Obtendo dados para o Pokémon 4/151: charmander
# Obtendo dados para o Pokémon 5/151: charmeleon
# Obtendo dados para o Pokémon 6/151: charizard
# Obtendo dados para o Pokémon 7/151: squirtle
# Obtendo dados para o Pokémon 8/151: wartortle
# Obtendo dados para o Pokémon 9/151: blastoise
# Obtendo dados para o Pokémon 10/151: caterpie
# Obtendo dados para o Pokémon 11/151: metapod
# Obtendo dados para o Pokémon 12/151: butterfree
# Obtendo dados para o Pokémon 13/151: weedle
# Obtendo dados para o Pokémon 14/151: kakuna
# Obtendo dados para o Pokémon 15/151: beedrill
# Obtendo dados para o Pokémon 16/151: pidgey
# Obtendo dados para o Pokémon 17/151: pidgeotto
# Obtendo dados para o Pokémon 18/151: pidgeot
# Obtendo dados para o Pokémon 19/151: rattata
# Obtendo dados para o Pokémon 20/151: raticate
# Obtendo dados para o Pokémon 21/151: spearow
# Obtendo dados para o Pokémon 22/151: fearow
# Obtendo dados para o Pokémon 23/151: ekans
# Obtendo dados para o Pokémon 24/151: arbok
# Obtendo dados para o Pokémon 25/151: pikachu
# Obtendo dados para o Pokémon 26/151: raichu
# Obtendo dados para o Pokémon 27/151: sandshrew
# Obtendo dados para o Pokémon 28/151: sandslash
# Obtendo dados para o Pokémon 29/151: nidoran-f
# Obtendo dados para o Pokémon 30/151: nidorina
# Obtendo dados para o Pokémon 31/151: nidoqueen
# Obtendo dados para o Pokémon 32/151: nidoran-m
# Obtendo dados para o Pokémon 33/151: nidorino
# Obtendo dados para o Pokémon 34/151: nidoking
# Obtendo dados para o Pokémon 35/151: clefairy
# Obtendo dados para o Pokémon 36/151: clefable
# Obtendo dados para o Pokémon 37/151: vulpix
# Obtendo dados para o Pokémon 38/151: ninetales
# Obtendo dados para o Pokémon 39/151: jigglypuff
# Obtendo dados para o Pokémon 40/151: wigglytuff
# Obtendo dados para o Pokémon 41/151: zubat
# Obtendo dados para o Pokémon 42/151: golbat
# Obtendo dados para o Pokémon 43/151: oddish
# Obtendo dados para o Pokémon 44/151: gloom
# Obtendo dados para o Pokémon 45/151: vileplume
# Obtendo dados para o Pokémon 46/151: paras
# Obtendo dados para o Pokémon 47/151: parasect
# Obtendo dados para o Pokémon 48/151: venonat
# Obtendo dados para o Pokémon 49/151: venomoth
# Obtendo dados para o Pokémon 50/151: diglett
# Obtendo dados para o Pokémon 51/151: dugtrio
# Obtendo dados para o Pokémon 52/151: meowth
# Obtendo dados para o Pokémon 53/151: persian
# Obtendo dados para o Pokémon 54/151: psyduck
# Obtendo dados para o Pokémon 55/151: golduck
# Obtendo dados para o Pokémon 56/151: mankey
# Obtendo dados para o Pokémon 57/151: primeape
# Obtendo dados para o Pokémon 58/151: growlithe
# Obtendo dados para o Pokémon 59/151: arcanine
# Obtendo dados para o Pokémon 60/151: poliwag
# Obtendo dados para o Pokémon 61/151: poliwhirl
# Obtendo dados para o Pokémon 62/151: poliwrath
# Obtendo dados para o Pokémon 63/151: abra
# Obtendo dados para o Pokémon 64/151: kadabra
# Obtendo dados para o Pokémon 65/151: alakazam
# Obtendo dados para o Pokémon 66/151: machop
# Obtendo dados para o Pokémon 67/151: machoke
# Obtendo dados para o Pokémon 68/151: machamp
# Obtendo dados para o Pokémon 69/151: bellsprout
# Obtendo dados para o Pokémon 70/151: weepinbell
# Obtendo dados para o Pokémon 71/151: victreebel
# Obtendo dados para o Pokémon 72/151: tentacool
# Obtendo dados para o Pokémon 73/151: tentacruel
# Obtendo dados para o Pokémon 74/151: geodude
# Obtendo dados para o Pokémon 75/151: graveler
# Obtendo dados para o Pokémon 76/151: golem
# Obtendo dados para o Pokémon 77/151: ponyta
# Obtendo dados para o Pokémon 78/151: rapidash
# Obtendo dados para o Pokémon 79/151: slowpoke
# Obtendo dados para o Pokémon 80/151: slowbro
# Obtendo dados para o Pokémon 81/151: magnemite
# Obtendo dados para o Pokémon 82/151: magneton
# Obtendo dados para o Pokémon 83/151: farfetchd
# Obtendo dados para o Pokémon 84/151: doduo
# Obtendo dados para o Pokémon 85/151: dodrio
# Obtendo dados para o Pokémon 86/151: seel
# Obtendo dados para o Pokémon 87/151: dewgong
# Obtendo dados para o Pokémon 88/151: grimer
# Obtendo dados para o Pokémon 89/151: muk
# Obtendo dados para o Pokémon 90/151: shellder
# Obtendo dados para o Pokémon 91/151: cloyster
# Obtendo dados para o Pokémon 92/151: gastly
# Obtendo dados para o Pokémon 93/151: haunter
# Obtendo dados para o Pokémon 94/151: gengar
# Obtendo dados para o Pokémon 95/151: onix
# Obtendo dados para o Pokémon 96/151: drowzee
# Obtendo dados para o Pokémon 97/151: hypno
# Obtendo dados para o Pokémon 98/151: krabby
# Obtendo dados para o Pokémon 99/151: kingler
# Obtendo dados para o Pokémon 100/151: voltorb
# Obtendo dados para o Pokémon 101/151: electrode
# Obtendo dados para o Pokémon 102/151: exeggcute
# Obtendo dados para o Pokémon 103/151: exeggutor
# Obtendo dados para o Pokémon 104/151: cubone
# Obtendo dados para o Pokémon 105/151: marowak
# Obtendo dados para o Pokémon 106/151: hitmonlee
# Obtendo dados para o Pokémon 107/151: hitmonchan
# Obtendo dados para o Pokémon 108/151: lickitung
# Obtendo dados para o Pokémon 109/151: koffing
# Obtendo dados para o Pokémon 110/151: weezing
# Obtendo dados para o Pokémon 111/151: rhyhorn
# Obtendo dados para o Pokémon 112/151: rhydon
# Obtendo dados para o Pokémon 113/151: chansey
# Obtendo dados para o Pokémon 114/151: tangela
# Obtendo dados para o Pokémon 115/151: kangaskhan
# Obtendo dados para o Pokémon 116/151: horsea
# Obtendo dados para o Pokémon 117/151: seadra
# Obtendo dados para o Pokémon 118/151: goldeen
# Obtendo dados para o Pokémon 119/151: seaking
# Obtendo dados para o Pokémon 120/151: staryu
# Obtendo dados para o Pokémon 121/151: starmie
# Obtendo dados para o Pokémon 122/151: mr-mime
# Obtendo dados para o Pokémon 123/151: scyther
# Obtendo dados para o Pokémon 124/151: jynx
# Obtendo dados para o Pokémon 125/151: electabuzz
# Obtendo dados para o Pokémon 126/151: magmar
# Obtendo dados para o Pokémon 127/151: pinsir
# Obtendo dados para o Pokémon 128/151: tauros
# Obtendo dados para o Pokémon 129/151: magikarp
# Obtendo dados para o Pokémon 130/151: gyarados
# Obtendo dados para o Pokémon 131/151: lapras
# Obtendo dados para o Pokémon 132/151: ditto
# Obtendo dados para o Pokémon 133/151: eevee
# Obtendo dados para o Pokémon 134/151: vaporeon
# Obtendo dados para o Pokémon 135/151: jolteon
# Obtendo dados para o Pokémon 136/151: flareon
# Obtendo dados para o Pokémon 137/151: porygon
# Obtendo dados para o Pokémon 138/151: omanyte
# Obtendo dados para o Pokémon 139/151: omastar
# Obtendo dados para o Pokémon 140/151: kabuto
# Obtendo dados para o Pokémon 141/151: kabutops
# Obtendo dados para o Pokémon 142/151: aerodactyl
# Obtendo dados para o Pokémon 143/151: snorlax
# Obtendo dados para o Pokémon 144/151: articuno
# Obtendo dados para o Pokémon 145/151: zapdos
# Obtendo dados para o Pokémon 146/151: moltres
# Obtendo dados para o Pokémon 147/151: dratini
# Obtendo dados para o Pokémon 148/151: dragonair
# Obtendo dados para o Pokémon 149/151: dragonite
# Obtendo dados para o Pokémon 150/151: mewtwo
# Obtendo dados para o Pokémon 151/151: mew
# Pokémons inseridos com sucesso no MongoDB!

# %% [markdown]
# # Vamos verificar se o RabbiMQ está pronto para receber os pokemons

# %%
import pika

def test_rabbitmq_connection(host, port, virtual_host, username, password):
    try:
        # Estabelecendo as credenciais e parâmetros de conexão
        credentials = pika.PlainCredentials(username, password)
        connection_parameters = pika.ConnectionParameters(host, port, virtual_host, credentials)

        # Tentando estabelecer a conexão
        connection = pika.BlockingConnection(connection_parameters)

        # Se chegou até aqui, significa que a conexão foi estabelecida com sucesso
        print("Conexão com o RabbitMQ estabelecida com sucesso!")

        # Fechando a conexão
        connection.close()

    except Exception as e:
        print(f"Erro ao tentar se conectar ao RabbitMQ: {e}")


# Testando a conexão
test_rabbitmq_connection('localhost', 5672, '/', 'user', 'password')
# Out:
# Conexão com o RabbitMQ estabelecida com sucesso!

# %% [markdown]
# # Enviando...

# %%
import pymongo
import pika
import json

# Configurações do MongoDB
MONGO_URI = "mongodb://localhost:27017/"
client = pymongo.MongoClient(MONGO_URI)
db = client["pokedex"]
collection = db["pokemons"]

# Configuração de conexão com o RabbitMQ
credentials = pika.PlainCredentials('user', 'password')
connection = pika.BlockingConnection(pika.ConnectionParameters('localhost', 5672, '/', credentials))
channel = connection.channel()

# Garantindo que a fila exista (se não existir, ela será criada)
channel.queue_declare(queue='pokemon_queue', durable=True)

# Lendo os registros do MongoDB
records = collection.find()

for record in records:
    # O ID do MongoDB não é serializável, então vamos removê-lo
    record['_id'] = str(record['_id'])

    # Enviando o registro para o RabbitMQ
    channel.basic_publish(exchange='',
                          routing_key='pokemon_queue',
                          body=json.dumps(record),
                          properties=pika.BasicProperties(
                              delivery_mode=2,  # torna a mensagem persistente
                          ))

print("Registros do MongoDB enviados para a fila do RabbitMQ!")
connection.close()
# Out:
# Registros do MongoDB enviados para a fila do RabbitMQ!
